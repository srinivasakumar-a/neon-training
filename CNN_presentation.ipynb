# %% [markdown]
# # Convolutional Neural Networks, Nervana Neon
#
# ### by:Reid Carper

# %% [markdown]
# # Overview:
#
# ### Convolutional Neural Networks (ConvNets or CNNs) are a category of Neural Networks that have proven very effective in areas such as image recognition and classification.
#
# ### Today we will focus on the flow of how a CNN ingests data, learns, and makes predictions in a Nervana Neon environment.

# %%
from IPython.display import Image
Image(filename='cnn.PNG')

# %% [raw]
# -Take an input image and use a feature detector(also be called filter) to detect.....features!
# -creates feature maps then move into sub sampling
# -features is how we see things, right? we need to teach this neural network how to 'see' the features we want to predict-point of feature map-removes unnesscary garabage
# -create multiple feature maps and network learns what filters to apply by training

# %%
Image(filename='featuremap.PNG')

# %% [raw]
# -Actually take the feature detector along each pixel on the image
# -Stride across each piece of the input image, can change-(reduce size of image by size of stride, easier to process, faster)

# %%
Image(filename='pooling.PNG')

# %% [raw]
# -used to still find features even if the image is tilted, animal looking a different way, actor has a different color shirt on..
# -rectified to make sure we keep the network non-linear
# -just like feature map on the input image, create a pooled feature map and a stride
# -find the MOST IMPORTANT the max() of the pixels in the image-produce 'pooled' features
# -another benefit is reducing the size of image again ~50-80% depending on stride size, preventing overfitting
# -explain overfitting

# %%
Image(filename='fully.PNG')

# %% [raw]
# -fully connected to the other hidden layer and the output layer, being connected to both makes it fully connected

# %%
Image(filename='full.PNG')

# %% [raw]
# -3 highlighted nuerons are features like tail, floppy ears and big nose
# -when the neurons are hightened the output neuron learns what features mean what during training process since the label
